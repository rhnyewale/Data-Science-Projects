# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pylab import rcParams
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

renewableMain = pd.read_excel('data/project/Renewable_new.xlsx')
renewableMain
# Out:
#          Month  Wood Energy Production Biofuels Production  \
# 0   1973-01-01                 129.630       Not Available
# 1   1973-02-01                 117.194       Not Available
# 2   1973-03-01                 129.763       Not Available
# 3   1973-04-01                 125.462       Not Available
# 4   1973-05-01                 129.624       Not Available
# ..         ...                     ...                 ...
# 559 2019-08-01                 210.748             199.004
# 560 2019-09-01                 196.224             182.097
# 561 2019-10-01                 195.969             191.976
# 562 2019-11-01                 196.174             191.984
# 563 2019-12-01                 204.442             203.487
#
#      Total Biomass Energy Production  Total Renewable Energy Production  \
# 0                            129.787                            403.981
# 1                            117.338                            360.900
# 2                            129.938                            400.161
# 3                            125.636                            380.470
# 4                            129.834                            392.141
# ..                               ...                                ...
# 559                          445.598                            948.508
# 560                          411.846                            897.703
# 561                          424.908                            934.159
# 562                          424.845                            925.253
# 563                          446.091                            968.130
#
#      Hydroelectric Power Consumption  Geothermal Energy Consumption  \
# 0                            272.703                          1.491
# 1                            242.199                          1.363
# 2                            268.810                          1.412
# 3                            253.185                          1.649
# 4                            260.770                          1.537
# ..                               ...                            ...
# 559                          191.854                         18.245
# 560                          148.840                         17.843
# 561                          148.548                         17.036
# 562                          187.101                         15.355
# 563                          202.475                         17.259
#
#     Solar Energy Consumption Wind Energy Consumption  Wood Energy Consumption  \
# 0              Not Available           Not Available                  129.630
# 1              Not Available           Not Available                  117.194
# 2              Not Available           Not Available                  129.763
# 3              Not Available           Not Available                  125.462
# 4              Not Available           Not Available                  129.624
# ..                       ...                     ...                      ...
# 559                  111.643                 181.168                  200.298
# 560                   96.829                 222.346                  186.503
# 561                   87.119                 256.547                  187.227
# 562                   64.499                 233.453                  186.792
# 563                   54.451                 247.854                  195.874
#
#      Waste Energy Consumption Biofuels Consumption  \
# 0                       0.157        Not Available
# 1                       0.144        Not Available
# 2                       0.176        Not Available
# 3                       0.174        Not Available
# 4                       0.210        Not Available
# ..                        ...                  ...
# 559                    35.846              196.527
# 560                    33.524              178.468
# 561                    36.963              190.275
# 562                    36.687              187.665
# 563                    38.162              192.749
#
#      Total Biomass Energy Consumption  Total Renewable Energy Consumption
# 0                             129.787                             403.981
# 1                             117.338                             360.900
# 2                             129.938                             400.161
# 3                             125.636                             380.470
# 4                             129.834                             392.141
# ..                                ...                                 ...
# 559                           432.671                             935.580
# 560                           398.496                             884.353
# 561                           414.465                             923.716
# 562                           411.144                             911.552
# 563                           426.785                             948.824
#
# [564 rows x 14 columns]

# %%
renewableMain.replace("Not Available",0)
# Out:
#          Month  Wood Energy Production  Biofuels Production  \
# 0   1973-01-01                 129.630                0.000
# 1   1973-02-01                 117.194                0.000
# 2   1973-03-01                 129.763                0.000
# 3   1973-04-01                 125.462                0.000
# 4   1973-05-01                 129.624                0.000
# ..         ...                     ...                  ...
# 559 2019-08-01                 210.748              199.004
# 560 2019-09-01                 196.224              182.097
# 561 2019-10-01                 195.969              191.976
# 562 2019-11-01                 196.174              191.984
# 563 2019-12-01                 204.442              203.487
#
#      Total Biomass Energy Production  Total Renewable Energy Production  \
# 0                            129.787                            403.981
# 1                            117.338                            360.900
# 2                            129.938                            400.161
# 3                            125.636                            380.470
# 4                            129.834                            392.141
# ..                               ...                                ...
# 559                          445.598                            948.508
# 560                          411.846                            897.703
# 561                          424.908                            934.159
# 562                          424.845                            925.253
# 563                          446.091                            968.130
#
#      Hydroelectric Power Consumption  Geothermal Energy Consumption  \
# 0                            272.703                          1.491
# 1                            242.199                          1.363
# 2                            268.810                          1.412
# 3                            253.185                          1.649
# 4                            260.770                          1.537
# ..                               ...                            ...
# 559                          191.854                         18.245
# 560                          148.840                         17.843
# 561                          148.548                         17.036
# 562                          187.101                         15.355
# 563                          202.475                         17.259
#
#      Solar Energy Consumption  Wind Energy Consumption  \
# 0                       0.000                    0.000
# 1                       0.000                    0.000
# 2                       0.000                    0.000
# 3                       0.000                    0.000
# 4                       0.000                    0.000
# ..                        ...                      ...
# 559                   111.643                  181.168
# 560                    96.829                  222.346
# 561                    87.119                  256.547
# 562                    64.499                  233.453
# 563                    54.451                  247.854
#
#      Wood Energy Consumption  Waste Energy Consumption  Biofuels Consumption  \
# 0                    129.630                     0.157                 0.000
# 1                    117.194                     0.144                 0.000
# 2                    129.763                     0.176                 0.000
# 3                    125.462                     0.174                 0.000
# 4                    129.624                     0.210                 0.000
# ..                       ...                       ...                   ...
# 559                  200.298                    35.846               196.527
# 560                  186.503                    33.524               178.468
# 561                  187.227                    36.963               190.275
# 562                  186.792                    36.687               187.665
# 563                  195.874                    38.162               192.749
#
#      Total Biomass Energy Consumption  Total Renewable Energy Consumption
# 0                             129.787                             403.981
# 1                             117.338                             360.900
# 2                             129.938                             400.161
# 3                             125.636                             380.470
# 4                             129.834                             392.141
# ..                                ...                                 ...
# 559                           432.671                             935.580
# 560                           398.496                             884.353
# 561                           414.465                             923.716
# 562                           411.144                             911.552
# 563                           426.785                             948.824
#
# [564 rows x 14 columns]

# %%
dropColsRenewable = ['Wood Energy Production','Biofuels Production','Total Biomass Energy Production','Total Renewable Energy Production']
renewableMain= renewableMain.drop(dropColsRenewable, axis=1)
renewableMain.head()
# Out:
#        Month  Hydroelectric Power Consumption  Geothermal Energy Consumption  \
# 0 1973-01-01                          272.703                          1.491
# 1 1973-02-01                          242.199                          1.363
# 2 1973-03-01                          268.810                          1.412
# 3 1973-04-01                          253.185                          1.649
# 4 1973-05-01                          260.770                          1.537
#
#   Solar Energy Consumption Wind Energy Consumption  Wood Energy Consumption  \
# 0            Not Available           Not Available                  129.630
# 1            Not Available           Not Available                  117.194
# 2            Not Available           Not Available                  129.763
# 3            Not Available           Not Available                  125.462
# 4            Not Available           Not Available                  129.624
#
#    Waste Energy Consumption Biofuels Consumption  \
# 0                     0.157        Not Available
# 1                     0.144        Not Available
# 2                     0.176        Not Available
# 3                     0.174        Not Available
# 4                     0.210        Not Available
#
#    Total Biomass Energy Consumption  Total Renewable Energy Consumption
# 0                           129.787                             403.981
# 1                           117.338                             360.900
# 2                           129.938                             400.161
# 3                           125.636                             380.470
# 4                           129.834                             392.141

# %%
emissionMain = pd.read_excel('data/project/emission_new.xlsx')
emissionMain
# Out:
#          Month  Coal, Including Coal Coke Net Imports, CO2 Emissions  \
# 0   1973-01-01                                            108.256
# 1   1973-02-01                                             97.667
# 2   1973-03-01                                             97.333
# 3   1973-04-01                                             93.052
# 4   1973-05-01                                             94.311
# ..         ...                                                ...
# 559 2019-08-01                                            103.486
# 560 2019-09-01                                             94.028
# 561 2019-10-01                                             78.219
# 562 2019-11-01                                             86.010
# 563 2019-12-01                                             84.258
#
#      Natural Gas, Excluding Supplemental Gaseous Fuels, CO2 Emissions  \
# 0                                              125.686
# 1                                              113.867
# 2                                              107.811
# 3                                               97.938
# 4                                               92.134
# ..                                                 ...
# 559                                            132.541
# 560                                            120.517
# 561                                            126.590
# 562                                            149.985
# 563                                            171.110
#
#      Aviation Gasoline CO2 Emissions  \
# 0                              0.428
# 1                              0.432
# 2                              0.459
# 3                              0.446
# 4                              0.549
# ..                               ...
# 559                            0.132
# 560                            0.149
# 561                            0.155
# 562                            0.125
# 563                            0.093
#
#      Distillate Fuel Oil, Excluding Biodiesel, CO2 Emissions  \
# 0                                               54.556
# 1                                               51.207
# 2                                               43.975
# 3                                               33.602
# 4                                               35.203
# ..                                                 ...
# 559                                             50.496
# 560                                             47.974
# 561                                             53.680
# 562                                             51.510
# 563                                             49.484
#
#      Hydrocarbon Gas Liquids CO2 Emissions  Jet Fuel CO2 Emissions  \
# 0                                   10.493                  13.778
# 1                                    8.874                  12.225
# 2                                    6.706                  12.325
# 3                                    5.809                  12.144
# 4                                    5.504                  13.792
# ..                                     ...                     ...
# 559                                  6.823                  23.008
# 560                                  7.289                  20.374
# 561                                  8.394                  21.504
# 562                                  9.539                  20.609
# 563                                 10.785                  22.209
#
#      Kerosene CO2 Emissions  Lubricants CO2 Emissions  \
# 0                     5.160                     1.039
# 1                     4.421                     1.027
# 2                     2.551                     1.107
# 3                     2.006                     0.981
# 4                     1.682                     1.159
# ..                      ...                       ...
# 559                   0.002                     0.774
# 560                   0.057                     0.677
# 561                   0.030                     0.907
# 562                   0.153                     0.722
# 563                   0.171                     0.656
#
#      Motor Gasoline, Excluding Ethanol, CO2 Emissions  \
# 0                                              70.901
# 1                                              67.377
# 2                                              75.482
# 3                                              73.367
# 4                                              80.052
# ..                                                ...
# 559                                           102.141
# 560                                            92.192
# 561                                            96.757
# 562                                            92.089
# 563                                            92.559
#
#      Petroleum Coke CO2 Emissions  Residual Fuel Oil CO2 Emissions  \
# 0                           4.743                           50.756
# 1                           3.904                           46.890
# 2                           4.260                           47.336
# 3                           4.087                           36.792
# 4                           4.543                           38.708
# ..                            ...                              ...
# 559                         6.671                            5.225
# 560                         5.372                            4.009
# 561                         4.693                            4.911
# 562                         6.600                            3.258
# 563                         7.158                            4.124
#
#      Other Petroleum Products CO2 Emissions  \
# 0                                     8.504
# 1                                     7.460
# 2                                     8.414
# 3                                     7.991
# 4                                     8.445
# ..                                      ...
# 559                                  11.538
# 560                                  10.754
# 561                                  11.266
# 562                                  10.922
# 563                                  10.790
#
#      Petroleum, Excluding Biofuels, CO2 Emissions  Total Energy CO2 Emissions
# 0                                         220.358                     454.300
# 1                                         203.817                     415.351
# 2                                         202.615                     407.758
# 3                                         177.227                     368.216
# 4                                         189.636                     376.081
# ..                                            ...                         ...
# 559                                       206.810                     443.779
# 560                                       188.847                     404.305
# 561                                       202.297                     408.049
# 562                                       195.527                     432.433
# 563                                       198.028                     454.339
#
# [564 rows x 15 columns]

# %%
sumCols = ['Aviation Gasoline CO2 Emissions','Hydrocarbon Gas Liquids CO2 Emissions','Jet Fuel CO2 Emissions','Kerosene CO2 Emissions','Lubricants CO2 Emissions','Petroleum Coke CO2 Emissions','Other Petroleum Products CO2 Emissions']

def sumOthers():
    sum = 0
    for i in range(len(sumCols)):
        sum = sum + emissionMain[sumCols[i]]
        
    emissionMain['Other Carbon Emission'] = sum


sumOthers()
emissionMain = emissionMain.drop(sumCols,axis = 1)
emissionMain
# Out:
#          Month  Coal, Including Coal Coke Net Imports, CO2 Emissions  \
# 0   1973-01-01                                            108.256
# 1   1973-02-01                                             97.667
# 2   1973-03-01                                             97.333
# 3   1973-04-01                                             93.052
# 4   1973-05-01                                             94.311
# ..         ...                                                ...
# 559 2019-08-01                                            103.486
# 560 2019-09-01                                             94.028
# 561 2019-10-01                                             78.219
# 562 2019-11-01                                             86.010
# 563 2019-12-01                                             84.258
#
#      Natural Gas, Excluding Supplemental Gaseous Fuels, CO2 Emissions  \
# 0                                              125.686
# 1                                              113.867
# 2                                              107.811
# 3                                               97.938
# 4                                               92.134
# ..                                                 ...
# 559                                            132.541
# 560                                            120.517
# 561                                            126.590
# 562                                            149.985
# 563                                            171.110
#
#      Distillate Fuel Oil, Excluding Biodiesel, CO2 Emissions  \
# 0                                               54.556
# 1                                               51.207
# 2                                               43.975
# 3                                               33.602
# 4                                               35.203
# ..                                                 ...
# 559                                             50.496
# 560                                             47.974
# 561                                             53.680
# 562                                             51.510
# 563                                             49.484
#
#      Motor Gasoline, Excluding Ethanol, CO2 Emissions  \
# 0                                              70.901
# 1                                              67.377
# 2                                              75.482
# 3                                              73.367
# 4                                              80.052
# ..                                                ...
# 559                                           102.141
# 560                                            92.192
# 561                                            96.757
# 562                                            92.089
# 563                                            92.559
#
#      Residual Fuel Oil CO2 Emissions  \
# 0                             50.756
# 1                             46.890
# 2                             47.336
# 3                             36.792
# 4                             38.708
# ..                               ...
# 559                            5.225
# 560                            4.009
# 561                            4.911
# 562                            3.258
# 563                            4.124
#
#      Petroleum, Excluding Biofuels, CO2 Emissions  Total Energy CO2 Emissions  \
# 0                                         220.358                     454.300
# 1                                         203.817                     415.351
# 2                                         202.615                     407.758
# 3                                         177.227                     368.216
# 4                                         189.636                     376.081
# ..                                            ...                         ...
# 559                                       206.810                     443.779
# 560                                       188.847                     404.305
# 561                                       202.297                     408.049
# 562                                       195.527                     432.433
# 563                                       198.028                     454.339
#
#      Other Carbon Emission
# 0                   44.145
# 1                   38.343
# 2                   35.822
# 3                   33.464
# 4                   35.674
# ..                     ...
# 559                 48.948
# 560                 44.672
# 561                 46.949
# 562                 48.670
# 563                 51.862
#
# [564 rows x 9 columns]

# %%
emissionMain = emissionMain[[c for c in emissionMain if c not in ['Total Energy CO2 Emissions']] + ['Total Energy CO2 Emissions']]
emissionMain
# Out:
#          Month  Coal, Including Coal Coke Net Imports, CO2 Emissions  \
# 0   1973-01-01                                            108.256
# 1   1973-02-01                                             97.667
# 2   1973-03-01                                             97.333
# 3   1973-04-01                                             93.052
# 4   1973-05-01                                             94.311
# ..         ...                                                ...
# 559 2019-08-01                                            103.486
# 560 2019-09-01                                             94.028
# 561 2019-10-01                                             78.219
# 562 2019-11-01                                             86.010
# 563 2019-12-01                                             84.258
#
#      Natural Gas, Excluding Supplemental Gaseous Fuels, CO2 Emissions  \
# 0                                              125.686
# 1                                              113.867
# 2                                              107.811
# 3                                               97.938
# 4                                               92.134
# ..                                                 ...
# 559                                            132.541
# 560                                            120.517
# 561                                            126.590
# 562                                            149.985
# 563                                            171.110
#
#      Distillate Fuel Oil, Excluding Biodiesel, CO2 Emissions  \
# 0                                               54.556
# 1                                               51.207
# 2                                               43.975
# 3                                               33.602
# 4                                               35.203
# ..                                                 ...
# 559                                             50.496
# 560                                             47.974
# 561                                             53.680
# 562                                             51.510
# 563                                             49.484
#
#      Motor Gasoline, Excluding Ethanol, CO2 Emissions  \
# 0                                              70.901
# 1                                              67.377
# 2                                              75.482
# 3                                              73.367
# 4                                              80.052
# ..                                                ...
# 559                                           102.141
# 560                                            92.192
# 561                                            96.757
# 562                                            92.089
# 563                                            92.559
#
#      Residual Fuel Oil CO2 Emissions  \
# 0                             50.756
# 1                             46.890
# 2                             47.336
# 3                             36.792
# 4                             38.708
# ..                               ...
# 559                            5.225
# 560                            4.009
# 561                            4.911
# 562                            3.258
# 563                            4.124
#
#      Petroleum, Excluding Biofuels, CO2 Emissions  Other Carbon Emission  \
# 0                                         220.358                 44.145
# 1                                         203.817                 38.343
# 2                                         202.615                 35.822
# 3                                         177.227                 33.464
# 4                                         189.636                 35.674
# ..                                            ...                    ...
# 559                                       206.810                 48.948
# 560                                       188.847                 44.672
# 561                                       202.297                 46.949
# 562                                       195.527                 48.670
# 563                                       198.028                 51.862
#
#      Total Energy CO2 Emissions
# 0                       454.300
# 1                       415.351
# 2                       407.758
# 3                       368.216
# 4                       376.081
# ..                          ...
# 559                     443.779
# 560                     404.305
# 561                     408.049
# 562                     432.433
# 563                     454.339
#
# [564 rows x 9 columns]

# %%
emisisonMain = emissionMain.set_index('Month')

plt.show(block=True)
plt.figure(figsize=(20,10))
plt.plot(emisisonMain)
# Out:
# [<matplotlib.lines.Line2D at 0x28db6397308>,
#  <matplotlib.lines.Line2D at 0x28db842d1c8>,
#  <matplotlib.lines.Line2D at 0x28db842d848>,
#  <matplotlib.lines.Line2D at 0x28db842da08>,
#  <matplotlib.lines.Line2D at 0x28db842dc08>,
#  <matplotlib.lines.Line2D at 0x28db842de08>,
#  <matplotlib.lines.Line2D at 0x28db842dfc8>,
#  <matplotlib.lines.Line2D at 0x28db8435208>]

# %%
productionMain = pd.read_csv('data/project/Production.csv', parse_dates = ['Month'])
productionMain
# Out:
#          Month  Coal Production  Natural Gas (Dry) Production  \
# 0   1973-01-01         1166.486                      1908.249
# 1   1973-02-01         1086.072                      1922.543
# 2   1973-03-01         1196.571                      1868.430
# 3   1973-04-01         1112.230                      1777.561
# 4   1973-05-01         1216.978                      1859.241
# ..         ...              ...                           ...
# 559 2019-08-01         1294.194                      2999.858
# 560 2019-09-01         1187.795                      2936.468
# 561 2019-10-01         1171.171                      3079.122
# 562 2019-11-01         1105.042                      2999.857
# 563 2019-12-01         1080.676                      3087.089
#
#      Crude Oil Production  Natural Gas Plant Liquids Production  \
# 0                1649.833                               209.366
# 1                1525.783                               196.405
# 2                1667.094                               216.151
# 3                1616.791                               211.002
# 4                1665.377                               216.746
# ..                    ...                                   ...
# 559              2187.617                               528.534
# 560              2133.079                               539.813
# 561              2238.732                               561.523
# 562              2198.766                               538.027
# 563              2257.300                               555.813
#
#      Total Fossil Fuels Production  Nuclear Electric Power Production  \
# 0                         4933.934                             68.103
# 1                         4730.803                             64.634
# 2                         4948.246                             72.494
# 3                         4717.583                             64.070
# 4                         4958.342                             62.111
# ..                             ...                                ...
# 559                       7010.202                            751.826
# 560                       6797.154                            690.695
# 561                       7050.548                            648.551
# 562                       6841.693                            670.431
# 563                       6980.878                            763.984
#
#      Hydroelectric Power Production  Geothermal Energy Production  \
# 0                           272.703                         1.491
# 1                           242.199                         1.363
# 2                           268.810                         1.412
# 3                           253.185                         1.649
# 4                           260.770                         1.537
# ..                              ...                           ...
# 559                         191.854                        18.245
# 560                         148.840                        17.843
# 561                         148.548                        17.036
# 562                         187.101                        15.355
# 563                         202.475                        17.259
#
#      Solar Energy Production  Wind Energy Production  \
# 0                      0.000                   0.000
# 1                      0.000                   0.000
# 2                      0.000                   0.000
# 3                      0.000                   0.000
# 4                      0.000                   0.000
# ..                       ...                     ...
# 559                  111.643                 181.168
# 560                   96.829                 222.346
# 561                   87.119                 256.547
# 562                   64.499                 233.453
# 563                   54.451                 247.854
#
#      Biomass Energy Production  Total Renewable Energy Production  \
# 0                      129.787                            403.981
# 1                      117.338                            360.900
# 2                      129.938                            400.161
# 3                      125.636                            380.470
# 4                      129.834                            392.141
# ..                         ...                                ...
# 559                    445.598                            948.508
# 560                    411.846                            897.703
# 561                    424.908                            934.159
# 562                    424.845                            925.253
# 563                    446.091                            968.130
#
#      Total Primary Energy Production
# 0                           5406.018
# 1                           5156.337
# 2                           5420.901
# 3                           5162.124
# 4                           5412.594
# ..                               ...
# 559                         8710.536
# 560                         8385.552
# 561                         8633.257
# 562                         8437.377
# 563                         8712.992
#
# [564 rows x 14 columns]

# %%
productionMain = productionMain.fillna(0)
productionMain
# Out:
#          Month  Coal Production  Natural Gas (Dry) Production  \
# 0   1973-01-01         1166.486                      1908.249
# 1   1973-02-01         1086.072                      1922.543
# 2   1973-03-01         1196.571                      1868.430
# 3   1973-04-01         1112.230                      1777.561
# 4   1973-05-01         1216.978                      1859.241
# ..         ...              ...                           ...
# 559 2019-08-01         1294.194                      2999.858
# 560 2019-09-01         1187.795                      2936.468
# 561 2019-10-01         1171.171                      3079.122
# 562 2019-11-01         1105.042                      2999.857
# 563 2019-12-01         1080.676                      3087.089
#
#      Crude Oil Production  Natural Gas Plant Liquids Production  \
# 0                1649.833                               209.366
# 1                1525.783                               196.405
# 2                1667.094                               216.151
# 3                1616.791                               211.002
# 4                1665.377                               216.746
# ..                    ...                                   ...
# 559              2187.617                               528.534
# 560              2133.079                               539.813
# 561              2238.732                               561.523
# 562              2198.766                               538.027
# 563              2257.300                               555.813
#
#      Total Fossil Fuels Production  Nuclear Electric Power Production  \
# 0                         4933.934                             68.103
# 1                         4730.803                             64.634
# 2                         4948.246                             72.494
# 3                         4717.583                             64.070
# 4                         4958.342                             62.111
# ..                             ...                                ...
# 559                       7010.202                            751.826
# 560                       6797.154                            690.695
# 561                       7050.548                            648.551
# 562                       6841.693                            670.431
# 563                       6980.878                            763.984
#
#      Hydroelectric Power Production  Geothermal Energy Production  \
# 0                           272.703                         1.491
# 1                           242.199                         1.363
# 2                           268.810                         1.412
# 3                           253.185                         1.649
# 4                           260.770                         1.537
# ..                              ...                           ...
# 559                         191.854                        18.245
# 560                         148.840                        17.843
# 561                         148.548                        17.036
# 562                         187.101                        15.355
# 563                         202.475                        17.259
#
#      Solar Energy Production  Wind Energy Production  \
# 0                      0.000                   0.000
# 1                      0.000                   0.000
# 2                      0.000                   0.000
# 3                      0.000                   0.000
# 4                      0.000                   0.000
# ..                       ...                     ...
# 559                  111.643                 181.168
# 560                   96.829                 222.346
# 561                   87.119                 256.547
# 562                   64.499                 233.453
# 563                   54.451                 247.854
#
#      Biomass Energy Production  Total Renewable Energy Production  \
# 0                      129.787                            403.981
# 1                      117.338                            360.900
# 2                      129.938                            400.161
# 3                      125.636                            380.470
# 4                      129.834                            392.141
# ..                         ...                                ...
# 559                    445.598                            948.508
# 560                    411.846                            897.703
# 561                    424.908                            934.159
# 562                    424.845                            925.253
# 563                    446.091                            968.130
#
#      Total Primary Energy Production
# 0                           5406.018
# 1                           5156.337
# 2                           5420.901
# 3                           5162.124
# 4                           5412.594
# ..                               ...
# 559                         8710.536
# 560                         8385.552
# 561                         8633.257
# 562                         8437.377
# 563                         8712.992
#
# [564 rows x 14 columns]

# %% [markdown]
# # Arima Model

# %%
emissionArima = emissionMain.copy()
dropColsArima = ['Coal, Including Coal Coke Net Imports, CO2 Emissions','Natural Gas, Excluding Supplemental Gaseous Fuels, CO2 Emissions','Distillate Fuel Oil, Excluding Biodiesel, CO2 Emissions','Motor Gasoline, Excluding Ethanol, CO2 Emissions','Residual Fuel Oil CO2 Emissions','Petroleum, Excluding Biofuels, CO2 Emissions','Other Carbon Emission']
emissionArima = emissionArima.drop(dropColsArima, axis=1)
emissionArima = emissionArima.set_index('Month')
emissionArima
# Out:
#             Total Energy CO2 Emissions
# Month
# 1973-01-01                     454.300
# 1973-02-01                     415.351
# 1973-03-01                     407.758
# 1973-04-01                     368.216
# 1973-05-01                     376.081
# ...                                ...
# 2019-08-01                     443.779
# 2019-09-01                     404.305
# 2019-10-01                     408.049
# 2019-11-01                     432.433
# 2019-12-01                     454.339
#
# [564 rows x 1 columns]

# %%
trainArima = emissionArima
testArima = emissionArima[480:564]
plt.plot(trainArima)
plt.plot(testArima)

# %%
testArima
# Out:
#             Total Energy CO2 Emissions
# Month
# 2013-01-01                     494.027
# 2013-02-01                     441.896
# 2013-03-01                     463.681
# 2013-04-01                     409.168
# 2013-05-01                     413.903
# ...                                ...
# 2019-08-01                     443.779
# 2019-09-01                     404.305
# 2019-10-01                     408.049
# 2019-11-01                     432.433
# 2019-12-01                     454.339
#
# [84 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pylab import rcParams
# %matplotlib inline

trainLog = np.log(trainArima)
plt.figure(figsize=(20,7))
plt.plot(trainLog)

# %%
rolling_mean_trainArima = trainLog.rolling(window=12).mean()
rolling_mean_trainArima
# Out:
#             Total Energy CO2 Emissions
# Month
# 1973-01-01                         NaN
# 1973-02-01                         NaN
# 1973-03-01                         NaN
# 1973-04-01                         NaN
# 1973-05-01                         NaN
# ...                                ...
# 2019-08-01                    6.069044
# 2019-09-01                    6.066984
# 2019-10-01                    6.063400
# 2019-11-01                    6.060418
# 2019-12-01                    6.057065
#
# [564 rows x 1 columns]

# %%
original = plt.plot(trainLog, color='blue', label='Original')
mean = plt.plot(rolling_mean_trainArima, color='red', label='Rolling mean')

plt.legend(loc='best')
plt.title("Rolling Mean")
plt.show(block=False)

# %%
# null-hypothesis : Data is Stationary

from statsmodels.tsa.stattools import adfuller

print('Results of Dickey-Fuller Test')
dftest = adfuller(trainLog['Total Energy CO2 Emissions'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistics', 'p-value', '#lags used', 'no. of observations used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value(%s)' %key] = value
    
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test
# Test Statistics              -1.667358
# p-value                       0.448004
# #lags used                   14.000000
# no. of observations used    549.000000
# Critical Value(1%)           -3.442317
# Critical Value(5%)           -2.866819
# Critical Value(10%)          -2.569582
# dtype: float64

# %%
trainArimaShift = trainLog - trainLog.shift()
plt.plot(trainArimaShift)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    #determining rolling ststistics
    movingAverage=timeseries.rolling(window=10).mean()
    movingStd= timeseries.rolling(window=1).std()
    
    #Plot rolling statistics
    orig = plt.plot(timeseries, color= 'blue', label = 'Original')
    mean = plt.plot(movingAverage, color = 'black', label = 'Rolling mean')
    plt.legend(loc='best')
    plt.title('Rolling mean')
    plt.show(block=False)
    
    
    #Dickey Fuller Test
    print('Results of Dickey Fuller Test')
    dftest = adfuller(timeseries["Total Energy CO2 Emissions"], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistics', 'p-value', '#lags used', 'no. of observations used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value(%s)' %key] = value
    print(dfoutput)

# %%
trainArimaShift.dropna(inplace=True)
test_stationarity(trainArimaShift)
# Out:
# Results of Dickey Fuller Test
# Test Statistics            -6.396861e+00
# p-value                     2.040679e-08
# #lags used                  1.300000e+01
# no. of observations used    5.490000e+02
# Critical Value(1%)         -3.442317e+00
# Critical Value(5%)         -2.866819e+00
# Critical Value(10%)        -2.569582e+00
# dtype: float64

# %%
#ACF and PACF plots
from statsmodels.tsa.stattools import acf,pacf

lag_acf = acf(trainArimaShift, nlags=40)
lag_pacf = pacf(trainArimaShift, nlags=40, method='ols')
#ols is Ordinary Least Squared method
#Plot ACF:
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.stem(lag_acf)
plt.axhline(y=0, linestyle='--', color='grey')
plt.axhline(y=-1.96/np.sqrt(len(trainArimaShift)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(trainArimaShift)), linestyle='--', color='gray')
plt.title('Autocorrelation Function')

#Plot PACF:
plt.subplot(122)
plt.stem(lag_pacf)
plt.axhline(y=0, linestyle='--', color='grey')
plt.axhline(y=-1.96/np.sqrt(len(trainArimaShift)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(trainArimaShift)), linestyle='--', color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.arima_model import ARIMA

#AR Model
model = ARIMA(trainLog, order=(2,1,2))
#(p,d,q)
results_ARIMA = model.fit()
plt.plot(trainArimaShift)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f' % sum((results_ARIMA.fittedvalues-trainArimaShift['Total Energy CO2 Emissions'])**2))
print('Plotting AR Model')
# Out:
# Plotting AR Model

# %%
from statsmodels.tsa.arima_model import ARIMA

#AR Model
model = ARIMA(trainLog, order=(11,1,6))
#(p,d,q)
results_ARIMA = model.fit()
plt.plot(trainArimaShift)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f' % sum((results_ARIMA.fittedvalues-trainArimaShift['Total Energy CO2 Emissions'])**2))
print('Plotting AR Model')
# Out:
# Plotting AR Model

# %%
results_ARIMA.fittedvalues
# Out:
# Month
# 1973-02-01    0.000190
# 1973-03-01    0.013048
# 1973-04-01    0.029108
# 1973-05-01    0.035832
# 1973-06-01    0.052438
#                 ...
# 2019-08-01    0.021908
# 2019-09-01   -0.035457
# 2019-10-01    0.041831
# 2019-11-01    0.016911
# 2019-12-01    0.012311
# Length: 563, dtype: float64

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
# Out:
# Month
# 1973-02-01    0.000190
# 1973-03-01    0.013048
# 1973-04-01    0.029108
# 1973-05-01    0.035832
# 1973-06-01    0.052438
# dtype: float64

# %%
#Convert to cumulative sum
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum.head())
# Out:
# Month
# 1973-02-01    0.000190
# 1973-03-01    0.013238
# 1973-04-01    0.042346
# 1973-05-01    0.078178
# 1973-06-01    0.130617
# dtype: float64

# %%
predictions_ARIMA_log = pd.Series(trainLog['Total Energy CO2 Emissions'].iloc[0], index=trainLog.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
predictions_ARIMA_log.head()
# Out:
# Month
# 1973-01-01    6.118758
# 1973-02-01    6.118947
# 1973-03-01    6.131996
# 1973-04-01    6.161104
# 1973-05-01    6.196936
# dtype: float64

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)

predictions_ARIMA
# Out:
# Month
# 1973-01-01    454.300000
# 1973-02-01    454.386147
# 1973-03-01    460.354049
# 1973-04-01    473.951038
# 1973-05-01    491.241589
#                  ...
# 2019-08-01    681.149892
# 2019-09-01    657.421703
# 2019-10-01    685.505537
# 2019-11-01    697.196727
# 2019-12-01    705.833228
# Length: 564, dtype: float64

# %%
plt.figure(figsize=(15,7))
plt.plot(trainArima)
plt.plot(predictions_ARIMA)

# %% [markdown]
# # Seasonality

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(emissionArima)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
plt.figure(figsize=(15,8))
plt.subplot(411)
plt.plot(trainLog, label = 'Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label = 'Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label = 'Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label = 'Residual')
plt.legend(loc='best')

# %% [markdown]
# # SARIMA Model

# %%
emissionSarima = emissionMain.copy()
dropColsArima = ['Coal, Including Coal Coke Net Imports, CO2 Emissions','Natural Gas, Excluding Supplemental Gaseous Fuels, CO2 Emissions','Distillate Fuel Oil, Excluding Biodiesel, CO2 Emissions','Motor Gasoline, Excluding Ethanol, CO2 Emissions','Residual Fuel Oil CO2 Emissions','Petroleum, Excluding Biofuels, CO2 Emissions','Other Carbon Emission']
emissionSarima = emissionSarima.drop(dropColsArima, axis=1)
emissionSarima = emissionSarima.set_index('Month')
emissionSarima
# Out:
#             Total Energy CO2 Emissions
# Month
# 1973-01-01                     454.300
# 1973-02-01                     415.351
# 1973-03-01                     407.758
# 1973-04-01                     368.216
# 1973-05-01                     376.081
# ...                                ...
# 2019-08-01                     443.779
# 2019-09-01                     404.305
# 2019-10-01                     408.049
# 2019-11-01                     432.433
# 2019-12-01                     454.339
#
# [564 rows x 1 columns]

# %%
percent_training = 0.85
splitPoint = round(len(emissionSarima) * percent_training)
training, testing = emissionSarima[0:splitPoint], emissionSarima[splitPoint:]

# %%
training = np.log(training)
training_diff = training.diff(periods=1).values[1:]

plt.plot(training_diff)

# %%
#ACF and PACF plots
from statsmodels.tsa.stattools import acf,pacf

lag_acf = acf(training_diff, nlags=40)
lag_pacf = pacf(training_diff, nlags=40, method='ols')
#ols is Ordinary Least Squared method
#Plot ACF:
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.stem(lag_acf)
# plt.plot(lag_acf)
plt.axhline(y=0, linestyle='--', color='grey')
plt.axhline(y=-1.96/np.sqrt(len(training_diff)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(training_diff)), linestyle='--', color='gray')
plt.title('Autocorrelation Function')

#Plot PACF:
plt.subplot(122)
plt.stem(lag_pacf)
plt.axhline(y=0, linestyle='--', color='grey')
plt.axhline(y=-1.96/np.sqrt(len(training_diff)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(training_diff)), linestyle='--', color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(training, order=(4,1,4), seasonal_order=(1,0,0,12), enforce_stationarity=False, enfoce_invertibility=False)
model_fit = model.fit(disp=False)

# %%
K  = len(testing)
forecast = model_fit.forecast(K)
forecast = np.exp(forecast)

plt.figure(figsize=(20,10))
plt.plot(forecast,'r')
plt.plot(emissionSarima,'b')
plt.autoscale(enable=True, axis='x', tight=True)
plt.axvline(x=emissionSarima.index[splitPoint], color='black');

# %%
predict = model_fit.predict(24,588)
exp_predict = np.exp(predict)
exp_predict

plt.figure(figsize=(20,10))
plt.plot(emissionSarima)
plt.plot(exp_predict)

# %%
emissionMain
# Out:
#          Month  Coal, Including Coal Coke Net Imports, CO2 Emissions  \
# 0   1973-01-01                                            108.256
# 1   1973-02-01                                             97.667
# 2   1973-03-01                                             97.333
# 3   1973-04-01                                             93.052
# 4   1973-05-01                                             94.311
# ..         ...                                                ...
# 559 2019-08-01                                            103.486
# 560 2019-09-01                                             94.028
# 561 2019-10-01                                             78.219
# 562 2019-11-01                                             86.010
# 563 2019-12-01                                             84.258
#
#      Natural Gas, Excluding Supplemental Gaseous Fuels, CO2 Emissions  \
# 0                                              125.686
# 1                                              113.867
# 2                                              107.811
# 3                                               97.938
# 4                                               92.134
# ..                                                 ...
# 559                                            132.541
# 560                                            120.517
# 561                                            126.590
# 562                                            149.985
# 563                                            171.110
#
#      Distillate Fuel Oil, Excluding Biodiesel, CO2 Emissions  \
# 0                                               54.556
# 1                                               51.207
# 2                                               43.975
# 3                                               33.602
# 4                                               35.203
# ..                                                 ...
# 559                                             50.496
# 560                                             47.974
# 561                                             53.680
# 562                                             51.510
# 563                                             49.484
#
#      Motor Gasoline, Excluding Ethanol, CO2 Emissions  \
# 0                                              70.901
# 1                                              67.377
# 2                                              75.482
# 3                                              73.367
# 4                                              80.052
# ..                                                ...
# 559                                           102.141
# 560                                            92.192
# 561                                            96.757
# 562                                            92.089
# 563                                            92.559
#
#      Residual Fuel Oil CO2 Emissions  \
# 0                             50.756
# 1                             46.890
# 2                             47.336
# 3                             36.792
# 4                             38.708
# ..                               ...
# 559                            5.225
# 560                            4.009
# 561                            4.911
# 562                            3.258
# 563                            4.124
#
#      Petroleum, Excluding Biofuels, CO2 Emissions  Other Carbon Emission  \
# 0                                         220.358                 44.145
# 1                                         203.817                 38.343
# 2                                         202.615                 35.822
# 3                                         177.227                 33.464
# 4                                         189.636                 35.674
# ..                                            ...                    ...
# 559                                       206.810                 48.948
# 560                                       188.847                 44.672
# 561                                       202.297                 46.949
# 562                                       195.527                 48.670
# 563                                       198.028                 51.862
#
#      Total Energy CO2 Emissions
# 0                       454.300
# 1                       415.351
# 2                       407.758
# 3                       368.216
# 4                       376.081
# ..                          ...
# 559                     443.779
# 560                     404.305
# 561                     408.049
# 562                     432.433
# 563                     454.339
#
# [564 rows x 9 columns]
